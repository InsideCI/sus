# %%
import re
from robobrowser import RoboBrowser
from bs4 import BeautifulSoup as soup


def all_courses():
    br = RoboBrowser(parser='lxml')
    br.open('https://sigaa.ufpb.br/sigaa/public/curso/lista.jsf?nivel=G&aba=p-ensino')

    src = str(br.parsed())
    page_soup = soup(src, "html.parser")

    all_courses = list()    

    container = page_soup.find("table", {"class":"listagem"})
    raw_data = container.find_all("tr")
    ids = container.find_all('a')

    raw_data = raw_data[1:]

    for each in raw_data:
        each = each.text.replace('\t', '').strip().split('\n')
        each = list(filter(None, each))

        all_courses.append(each)


    all_courses = list(filter(lambda x: len(x) >1, all_courses))

    for i in range(0, len(ids)):
            s = ids[i]['href']
            result = re.search("id=(.+?)&", s)
            ids[i] = result.group(1)

    for i in range(0, len(ids)):
        all_courses[i].insert(0, ids[i])

    return all_courses


all_courses()
# Out:
# [['1626776',
#   'BIOTECNOLOGIA',
#   'João Pessoa',
#   'Presencial',
#   'RAFAEL DE ALMEIDA TRAVASSOS'],
#  ['1626755',
#   'AGRONOMIA - AR',
#   'Areia',
#   'Presencial',
#   'BRUNO DE OLIVEIRA DIAS'],
#  ['1626780',
#   'CIÊNCIAS BIOLÓGICAS- AREIA',
#   'Areia',
#   'Presencial',
#   'ABRAAO RIBEIRO BARBOSA'],
#  ['1626810',
#   'MEDICINA VETERINÁRIA - AREIA',
#   'Areia',
#   'Presencial',
#   'FABIANA SATAKE'],
#  ['1626770',
#   'QUÍMICA - AREIA',
#   'Areia',
#   'Presencial',
#   'SIDNEY RAMOS DE SANTANA'],
#  ['1626754',
#   'ZOOTECNIA - AREIA',
#   'Areia',
#   'Presencial',
#   'ADRIANA EVANGELISTA RODRIGUES'],
#  ['11449719',
#   'ADMINISTRAÇÃO',
#   'Mamanguape',
#   'Presencial',
#   'MARCIA MARIA DE MEDEIROS TRAVASSOS SAEGER'],
#  ['1626862',
#   'ANTROPOLOGIA -CCAE',
#   'Rio Tinto',
#   'Presencial',
#   'KELLY EMANUELLY DE OLIVEIRA'],
#  ['1626786',
#   'CIÊNCIA DA COMPUTAÇÃO-CCAE',
#   'Rio Tinto',
#   'Presencial',
#   'PASQUELINE DANTAS SCAICO'],
#  ['1626789',
#   'CIÊNCIAS CONTÁBEIS - CCAE',
#   'Mamanguape',
#   'Presencial',
#   'JOSE JASSUIPE DA SILVA MORAIS'],
#  ['1626836',
#   'DESIGN - CCAE',
#   'Rio Tinto',
#   'Presencial',
#   'ANGELICA DE SOUZA GALDINO ACIOLY'],
#  ['1626787',
#   'ECOLOGIA- CCAE',
#   'Rio Tinto',
#   'Presencial',
#   'EVIO EDUARDO CHAVES DE MELO'],
#  ['1626790',
#   'HOTELARIA',
#   'Mamanguape',
#   'Presencial',
#   'MARIANA BUENO DE ANDRADE MATOS'],
#  ['1626874',
#   'LETRAS- CCAE',
#   'Mamanguape',
#   'Presencial',
#   'MOAMA LORENA DE LACERDA MARQUES'],
#  ['2663760',
#   'LETRAS (LÍNGUA ESPANHOLA) - EAD',
#   'Mamanguape',
#   'A Distância',
#   'RUTH MARCELA BOWN CUELLO'],
#  ['2051542',
#   'LETRAS (LÍNGUA INGLESA) -EAD',
#   'Mamanguape',
#   'A Distância',
#   'SANDRA MARIA ARAUJO DIAS'],
#  ['1626785',
#   'MATEMÁTICA (LICENCIATURA) - CCAE',
#   'Rio Tinto',
#   'Presencial',
#   'CLAUDILENE GOMES DA COSTA'],
#  ['1626838',
#   'PEDAGOGIA - CCAE',
#   'Mamanguape',
#   'Presencial',
#   'ALINE CLEIDE BATISTA'],
#  ['1626793',
#   'SECRETARIADO EXECUTIVO BILÍNGUE - CCAE',
#   'Mamanguape',
#   'Presencial',
#   'CIBELLE DA SILVA SANTIAGO'],
#  ['1626837',
#   'SISTEMAS DE INFORMAÇÃO - CCAE',
#   'Rio Tinto',
#   'Presencial',
#   'JULIANA DE ALBUQUERQUE GONCALVES SARAIVA'],
#  ['7906146',
#   'BIOMEDICINA',
#   'João Pessoa',
#   'Presencial',
#   'BRUNO HENRIQUE ANDRADE GALVAO'],
#  ['2663771',
#   'EDUCAÇÃO FÍSICA - BACHARELADO',
#   'João Pessoa',
#   'Presencial',
#   'AMILTON DA CRUZ SANTOS'],
#  ['1626645',
#   'EDUCAÇÃO FÍSICA - LICENCIATURA',
#   'João Pessoa',
#   'Presencial',
#   'MELINA SILVA ALVES'],
#  ['1626663',
#   'ENFERMAGEM',
#   'João Pessoa',
#   'Presencial',
#   'ORIANA DEYZE CORREIA PAIVA LEADEBAL'],
#  ['1626729',
#   'FARMÁCIA',
#   'João Pessoa',
#   'Presencial',
#   'ROBSON CAVALCANTE VERAS'],
#  ['1626867',
#   'FISIOTERAPIA',
#   'João Pessoa',
#   'Presencial',
#   'GERALDO EDUARDO GUEDES DE BRITO'],
#  ['1626815',
#   'FONOAUDIOLOGIA',
#   'João Pessoa',
#   'Presencial',
#   'ANA KARENINA DE FREITAS JORDAO DO AMARAL'],
#  ['1626733',
#   'NUTRIÇÃO',
#   'João Pessoa',
#   'Presencial',
#   'SONIA CRISTINA PEREIRA DE OLIVEIRA RAMALHO DINIZ'],
#  ['1626646',
#   'ODONTOLOGIA',
#   'João Pessoa',
#   'Presencial',
#   'ANDREA GADELHA RIBEIRO TARGINO'],
#  ['1626813',
#   'TERAPIA OCUPACIONAL',
#   'João Pessoa',
#   'Presencial',
#   'BARBARA IANSA DE LIMA BARROSO'],
#  ['1626855',
#   'CIÊNCIAS BIOLÓGICAS',
#   'João Pessoa',
#   'Presencial',
#   'CRISTINE HIRSCH MONTEIRO'],
#  ['5505677',
#   'CIÊNCIAS BIOLÓGICAS',
#   'João Pessoa',
#   'Presencial',
#   'HUGO ENRIQUE MENDEZ GARCIA'],
#  ['1626846',
#   'CIÊNCIAS BIOLÓGICAS - EAD',
#   'João Pessoa',
#   'A Distância',
#   'RAFAEL ANGEL TORQUEMADA GUERRA'],
#  ['1813971',
#   'COMPUTAÇÃO / EAD',
#   'João Pessoa',
#   'A Distância',
#   'DANIELLE ROUSY DIAS DA SILVA'],
#  ['1626868',
#   'ESTATÍSTICA',
#   'João Pessoa',
#   'Presencial',
#   'MARIA LIDIA COCO TERRA'],
#  ['1626675',
#   'FÍSICA',
#   'João Pessoa',
#   'Presencial',
#   'ELADIO JOSE DE GOES BRENNAND'],
#  ['4028601',
#   'GEOGRAFIA',
#   'João Pessoa',
#   'Presencial',
#   'FILLIPE SILVEIRA MARINI'],
#  ['1626651',
#   'GEOGRAFIA',
#   'João Pessoa',
#   'Presencial',
#   'FILLIPE SILVEIRA MARINI'],
#  ['1626681',
#   'MATEMÁTICA',
#   'João Pessoa',
#   'Presencial',
#   'ANTONIO SALES DA SILVA'],
#  ['1626841',
#   'MATEMÁTICA - EAD',
#   'João Pessoa',
#   'A Distância',
#   'JOSE GOMES DE ASSIS'],
#  ['1626799', 'QUÍMICA', 'João Pessoa', 'Presencial', 'ARY DA SILVA MAIA'],
#  ['1626869',
#   'CIÊNCIAS SOCIAIS',
#   'João Pessoa',
#   'Presencial',
#   'TERENCE MULHALL'],
#  ['1626827',
#   'COMUNICAÇÃO EM MÍDIAS DIGITAIS',
#   'João Pessoa',
#   'Presencial',
#   'OLAVO ANTONIO SARAIVA MENDES'],
#  ['1626711',
#   'FILOSOFIA',
#   'João Pessoa',
#   'Presencial',
#   'GILFRANCO LUCENA DOS SANTOS'],
#  ['1626832',
#   'HISTÓRIA',
#   'João Pessoa',
#   'Presencial',
#   'PAULO ROBERTO DE AZEVEDO MAIA'],
#  ['2663764', 'HISTORIA ( MSC)', 'João Pessoa', 'Presencial'],
#  ['1626872', 'LETRAS', 'João Pessoa', 'Presencial', 'CIRINEU CECOTE STEIN'],
#  ['1626844',
#   'LETRAS / EAD',
#   'João Pessoa',
#   'A Distância',
#   'ANA CLAUDIA FELIX GUALBERTO'],
#  ['2663763',
#   'LETRAS - LIBRAS /EAD',
#   'João Pessoa',
#   'A Distância',
#   'NAYARA DE ALMEIDA ADRIANO'],
#  ['2663753',
#   'LETRAS (LÍNGUA ESPANHOLA)',
#   'João Pessoa',
#   'Presencial',
#   'CIRINEU CECOTE STEIN'],
#  ['4057805',
#   'LETRAS (LÍNGUA FRANCESA)',
#   'João Pessoa',
#   'Presencial',
#   'CIRINEU CECOTE STEIN'],
#  ['2663739',
#   'LETRAS (LÍNGUAS CLÁSSICAS)',
#   'João Pessoa',
#   'Presencial',
#   'MARCO VALERIO CLASSE COLONNELLI'],
#  ['2663749',
#   'LETRAS (LÍNGUAS INGLESA)',
#   'João Pessoa',
#   'Presencial',
#   'CIRINEU CECOTE STEIN'],
#  ['1626814',
#   'LÍNGUAS ESTRANGEIRAS APLICADAS ÀS NEGOCIAÇÕES INTERNACIONAIS',
#   'João Pessoa',
#   'Presencial',
#   'SILVIA RENATA RIBEIRO'],
#  ['1626724',
#   'PSICOLOGIA',
#   'João Pessoa',
#   'Presencial',
#   'MIRIANE DA SILVA SANTOS BARBOZA'],
#  ['1626882',
#   'SERVIÇO SOCIAL',
#   'João Pessoa',
#   'Presencial',
#   'VALERIA COSTA ALDECI DE OLIVEIRA'],
#  ['1626816',
#   'TRADUÇÃO',
#   'João Pessoa',
#   'Presencial',
#   'CAMILA NATHALIA DE OLIVEIRA BRAGA'],
#  ['1626764',
#   'ADMINISTRAÇÃO - CCHSA',
#   'Bananeiras',
#   'Presencial',
#   'GABRIELA TAVARES DOS SANTOS'],
#  ['1626662',
#   'AGROECOLOGIA - CCHSA',
#   'Bananeiras',
#   'Presencial',
#   'SILVANIA MARIA DE SOUZA GOMES NASCIMENTO'],
#  ['1626648',
#   'AGROINDÚSTRIA - CCHSA',
#   'Bananeiras',
#   'Presencial',
#   'LAESIO PEREIRA MARTINS'],
#  ['1626758',
#   'CIÊNCIAS AGRÁRIAS',
#   'Bananeiras',
#   'Presencial',
#   'THIAGO JARDELINO DIAS'],
#  ['1626847',
#   'CIÊNCIAS AGRÁRIAS -EAD',
#   'Bananeiras',
#   'A Distância',
#   'MARCOS BARROS DE MEDEIROS'],
#  ['1626877',
#   'PEDAGOGIA - CCHSA',
#   'Bananeiras',
#   'Presencial',
#   'SILVÂNIA LÚCIA DE ARAÚJO SILVA'],
#  ['1626727',
#   'DIREITO',
#   'João Pessoa',
#   'Presencial',
#   'MARCIA GLEBYANE MACIEL QUIRINO'],
#  ['1626880', 'DIREITO', 'Santa Rita', 'Presencial', 'GISCARD FARIAS AGRA'],
#  ['1626795',
#   'MEDICINA',
#   'João Pessoa',
#   'Presencial',
#   'JOSE GIVALDO MELQUIADES DE MEDEIROS'],
#  ['1626692',
#   'ADMINISTRAÇÃO',
#   'João Pessoa',
#   'Presencial',
#   'ANA CAROLINA KRUTA DE ARAUJO BISPO'],
#  ['1813969',
#   'ADMINISTRAÇÃO PÚBLICA / EAD',
#   'João Pessoa',
#   'A Distância',
#   'SABRINA DE MELO CABRAL'],
#  ['1626802', 'ARQUIVOLOGIA (BACHARELADO)', 'João Pessoa', 'Presencial'],
#  ['1626693',
#   'BIBLIOTECONOMIA',
#   'João Pessoa',
#   'Presencial',
#   'ROSA ZULEIDE LIMA DE BRITO'],
#  ['1626665',
#   'CIÊNCIAS ATUARIAIS',
#   'João Pessoa',
#   'Presencial',
#   'VICTOR HUGO DIAS DIOGENES'],
#  ['1626694',
#   'CIÊNCIAS CONTÁBEIS',
#   'João Pessoa',
#   'Presencial',
#   'MOISES ARAUJO ALMEIDA'],
#  ['1626696',
#   'CIÊNCIAS ECONÔMICAS',
#   'João Pessoa',
#   'Presencial',
#   'ADRIANO FIRMINO VALDEVINO DE ARAUJO'],
#  ['5766890',
#   'GESTÃO PÚBLICA',
#   'João Pessoa',
#   'Presencial',
#   'JOSENEIDE SOUZA PESSOA'],
#  ['1626850',
#   'RELACÕES INTERNACIONAIS',
#   'João Pessoa',
#   'Presencial',
#   'ALINE CONTTI CASTRO'],
#  ['1626826',
#   'TECNOLOGIA EM GESTÃO PÚBLICA',
#   'João Pessoa',
#   'Presencial',
#   'JOSENEIDE SOUZA PESSOA'],
#  ['1626843',
#   'ARTES VISUAIS',
#   'João Pessoa',
#   'Presencial',
#   'MARCO AURELIO ALCANTARA DAMACENO'],
#  ['1626772',
#   'CINEMA E AUDIOVISUAL',
#   'João Pessoa',
#   'Presencial',
#   'FERNANDO TREVAS FALCONE'],
#  ['1626656', 'COMUNICAÇÃO SOCIAL', 'João Pessoa', 'Presencial'],
#  ['1813968',
#   'DANÇA LICENCIATURA',
#   'João Pessoa',
#   'Presencial',
#   'CANDICE DIDONET'],
#  ['2291377',
#   'HOTELARIA',
#   'João Pessoa',
#   'Presencial',
#   'MARIANA BUENO DE ANDRADE MATOS'],
#  ['1626775',
#   'JORNALISMO',
#   'João Pessoa',
#   'Presencial',
#   'FABIANA CARDOSO DE SIQUEIRA'],
#  ['1626778',
#   'MÚSICA',
#   'João Pessoa',
#   'Presencial',
#   'VANILDO MOUSINHO MARINHO'],
#  ['2675573',
#   'MÚSICA - BACHARELADO',
#   'João Pessoa',
#   'Presencial',
#   'GERALDO DIAS DA ROCHA JUNIOR'],
#  ['1626881',
#   'MUSICA POPULAR',
#   'João Pessoa',
#   'Presencial',
#   'LEONARDO MEIRA DANTAS'],
#  ['1626774', 'RADIALISMO', 'João Pessoa', 'Presencial'],
#  ['1626823',
#   'REGÊNCIA DE BANDAS E FANFARRAS',
#   'João Pessoa',
#   'Presencial',
#   'SANDOVAL MORENO DE OLIVEIRA'],
#  ['1626773',
#   'RELAÇÕES PÚBLICAS',
#   'João Pessoa',
#   'Presencial',
#   'ANDREA KARINNE ALBUQUERQUE MAIA'],
#  ['2663765',
#   'TEATRO (BACHARELADO)',
#   'João Pessoa',
#   'Presencial',
#   'VICTOR HUGO NEVES DE OLIVEIRA'],
#  ['1626842',
#   'TEATRO (LICENCIATURA)',
#   'João Pessoa',
#   'Presencial',
#   'MARCIA CHIAMULERA'],
#  ['1626743', 'TURISMO', 'João Pessoa', 'Presencial', 'FABIANE NAGABE'],
#  ['1626768',
#   'CIÊNCIAS DAS RELIGIÕES',
#   'João Pessoa',
#   'Presencial',
#   'ANA PAULA RODRIGUES CAVALCANTI'],
#  ['1626848',
#   'CIÊNCIAS NATURAIS - EAD',
#   'João Pessoa',
#   'A Distância',
#   'MARIA DE LOURDES PEREIRA'],
#  ['1626698',
#   'PEDAGOGIA',
#   'João Pessoa',
#   'Presencial',
#   'ANA LUISA NOGUEIRA DE AMORIM'],
#  ['1626845',
#   'PEDAGOGIA - EAD',
#   'João Pessoa',
#   'A Distância',
#   'EDSON CARVALHO GUEDES'],
#  ['2699762', 'PEDAGOGIA (EDUCAÇÃO DO CAMPO)', 'João Pessoa', 'Presencial'],
#  ['2663759', 'PEDAGOGIA (MSC)', 'João Pessoa', 'Presencial'],
#  ['1626818',
#   'PSICOPEDAGOGIA (BACH)',
#   'João Pessoa',
#   'Presencial',
#   'EDER DA SILVA DANTAS'],
#  ['1626777',
#   'ENGENHARIA DE ENERGIAS RENOVÁVEIS',
#   'João Pessoa',
#   'Presencial',
#   'LEVI PEDRO BARBOSA DE OLIVEIRA'],
#  ['1626808',
#   'ENGENHARIA ELÉTRICA',
#   'João Pessoa',
#   'Presencial',
#   'ALEXSANDRO JOSÉ VIRGINIO DOS SANTOS'],
#  ['1626669',
#   'CIÊNCIA DA COMPUTAÇÃO',
#   'João Pessoa',
#   'Presencial',
#   'GUSTAVO HENRIQUE MATOS BEZERRA MOTTA'],
#  ['1626865',
#   'ENGENHARIA DE COMPUTAÇÃO',
#   'João Pessoa',
#   'Presencial',
#   'THAIS GAUDENCIO DO REGO'],
#  ['1626769',
#   'MATEMÁTICA COMPUTACIONAL',
#   'João Pessoa',
#   'Presencial',
#   'ROBERTO QUIRINO DO NASCIMENTO'],
#  ['1626736',
#   'ARQUITETURA E URBANISMO',
#   'João Pessoa',
#   'Presencial',
#   'CLAUDIA VERONICA TORRES BARBOSA'],
#  ['1626806',
#   'ENGENHARIA AMBIENTAL',
#   'João Pessoa',
#   'Presencial',
#   'ELISANGELA MARIA RODRIGUES ROCHA'],
#  ['1626738',
#   'ENGENHARIA CIVIL',
#   'João Pessoa',
#   'Presencial',
#   'ANDREA BRASILIANO SILVA'],
#  ['1626740',
#   'ENGENHARIA DE ALIMENTOS',
#   'João Pessoa',
#   'Presencial',
#   'YURI MONTENEGRO ISHIHARA'],
#  ['1626809',
#   'ENGENHARIA DE MATERIAIS',
#   'João Pessoa',
#   'Presencial',
#   'AMELIA SEVERINO FERREIRA E SANTOS'],
#  ['1626849',
#   'ENGENHARIA DE PRODUCAO',
#   'João Pessoa',
#   'Presencial',
#   'JULIANA MACHION GONCALVES'],
#  ['1626741',
#   'ENGENHARIA DE PRODUÇÃO MECÂNICA',
#   'João Pessoa',
#   'Presencial',
#   'JAILSON RIBEIRO DE OLIVEIRA'],
#  ['1626866',
#   'ENGENHARIA MECÂNICA',
#   'João Pessoa',
#   'Presencial',
#   'RAFAEL EVARISTO CALUÊTE'],
#  ['1626804',
#   'ENGENHARIA QUÍMICA',
#   'João Pessoa',
#   'Presencial',
#   'LEOPOLDO OSWALDO ALCAZAR ROJAS'],
#  ['1626647',
#   'QUÍMICA INDUSTRIAL',
#   'João Pessoa',
#   'Presencial',
#   'RAUL ROSENHAIM'],
#  ['1976359',
#   'GASTRONOMIA',
#   'João Pessoa',
#   'Presencial',
#   'KARLLA KARINNE GOMES DE OLIVEIRA'],
#  ['1626859',
#   'TECNOLOGIA DE ALIMENTOS',
#   'João Pessoa',
#   'Presencial',
#   'ISMAEL IVAN ROCKENBACH'],
#  ['1626861',
#   'TECNOLOGIA EM PRODUÇÃO SUCROALCOOLEIRA',
#   'João Pessoa',
#   'Presencial',
#   'JOELMA MORAIS FERREIRA']]
